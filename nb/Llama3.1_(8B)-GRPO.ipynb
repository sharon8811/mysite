# %% [markdown]
# <a href="https://colab.research.google.com/github/sharon8811/mysite/blob/master/nb/Llama3.1_(8B)-GRPO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://docs.unsloth.ai/get-started/installing-+-updating).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# **Read our [Gemma 3 blog](https://unsloth.ai/blog/gemma3) for what's new in Unsloth and our [Reasoning blog](https://unsloth.ai/blog/r1-reasoning) on how to train reasoning models.**
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth vllm
else:
    # [NOTE] Do the below ONLY in Colab! Use [[pip install unsloth vllm]]
    # !pip install --no-deps unsloth vllm

# %%
#@title Colab Extra Install { display-mode: "form" }
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth vllm
else:
    # !pip install --no-deps unsloth vllm
    # [NOTE] Do the below ONLY in Colab! Use [[pip install unsloth vllm]]
    # Skip restarting message in Colab
    import sys, re, requests; modules = list(sys.modules.keys())
    for x in modules: sys.modules.pop(x) if "PIL" in x or "google" in x else None
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft "trl==0.15.2" triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf datasets huggingface_hub hf_transfer

    # vLLM requirements - vLLM breaks Colab due to reinstalling numpy
    f = requests.get("https://raw.githubusercontent.com/vllm-project/vllm/refs/heads/main/requirements/common.txt").content
    with open("vllm_requirements.txt", "wb") as file:
        file.write(re.sub(rb"(transformers|numpy|xformers)[^\n]{1,}\n", b"", f))
    # !pip install -r vllm_requirements.txt

# %% [markdown]
# ### Unsloth

# %% [markdown]
# Load up `Llama 3.1 8B Instruct`, and set parameters

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 1024 # Can increase for longer reasoning traces
lora_rank = 32 # Larger rank = smarter, but slower

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "meta-llama/meta-Llama-3.1-8B-Instruct",
    max_seq_length = max_seq_length,
    load_in_4bit = True, # False for LoRA 16bit
    fast_inference = True, # Enable vLLM fast inference
    max_lora_rank = lora_rank,
    gpu_memory_utilization = 0.6, # Reduce if out of memory
)

model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ], # Remove QKVO if out of memory
    lora_alpha = lora_rank,
    use_gradient_checkpointing = "unsloth", # Enable long context finetuning
    random_state = 3407,
)
# Out:
# Unsloth: Patching Xformers to fix some performance issues.
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 03-07 09:37:36 __init__.py:207] Automatically detected platform cuda.
# ==((====))==  Unsloth 2025.3.8: Fast Llama patching. Transformers: 4.48.3. vLLM: 0.7.3.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: vLLM loading unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit with actual GPU utilization = 59.43%
# Unsloth: Your GPU has CUDA compute capability 7.5 with VRAM = 14.74 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 1024. Num Sequences = 160.
# Unsloth: vLLM's KV Cache can use up to 2.59 GB. Also swap space = 2 GB.
# WARNING 03-07 09:37:43 config.py:2448] Casting torch.bfloat16 to torch.float16.
# INFO 03-07 09:37:57 config.py:549] This model supports multiple tasks: {'score', 'classify', 'reward', 'embed', 'generate'}. Defaulting to 'generate'.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'float16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection', 'model.layers.1.mlp'], 'llm_int8_threshold': 6.0}
# INFO 03-07 09:37:57 llm_engine.py:234] Initializing a V0 LLM engine (v0.7.3) with config: model='unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit', speculative_config=None, tokenizer='unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=1024, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda:0, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":0,"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":160}, use_cached_outputs=False,
# tokenizer_config.json:   0%|          | 0.00/55.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# INFO 03-07 09:38:03 cuda.py:178] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# INFO 03-07 09:38:03 cuda.py:226] Using XFormers backend.
# INFO 03-07 09:38:03 model_runner.py:1110] Starting to load model unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit...
# INFO 03-07 09:38:04 loader.py:1089] Loading weights with BitsAndBytes quantization.  May take a while ...
# INFO 03-07 09:38:05 weight_utils.py:254] Using model weights format ['*.safetensors']
# model.safetensors:   0%|          | 0.00/5.96G [00:00<?, ?B/s]
# INFO 03-07 09:38:52 weight_utils.py:270] Time spent downloading weights for unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit: 46.653482 seconds
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 03-07 09:39:34 model_runner.py:1115] Loading model weights took 5.5976 GB
# INFO 03-07 09:39:34 punica_selector.py:18] Using PunicaWrapperGPU.
# INFO 03-07 09:39:49 worker.py:267] Memory profiling takes 14.16 seconds
# INFO 03-07 09:39:49 worker.py:267] the current vLLM instance can use total_gpu_memory (14.74GiB) x gpu_memory_utilization (0.59) = 8.76GiB
# INFO 03-07 09:39:49 worker.py:267] model weights take 5.60GiB; non_torch_memory takes 0.03GiB; PyTorch activation peak memory takes 0.74GiB; the rest of the memory reserved for KV Cache is 2.39GiB.
# INFO 03-07 09:39:50 executor_base.py:111] # cuda blocks: 1224, # CPU blocks: 1024
# INFO 03-07 09:39:50 executor_base.py:116] Maximum concurrency for 1024 tokens per request: 19.12x
# INFO 03-07 09:39:51 model_runner.py:1434] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes: 100%|██████████| 23/23 [00:43<00:00,  1.88s/it]
# INFO 03-07 09:40:35 model_runner.py:1562] Graph capturing finished in 43 secs, took 0.59 GiB
# INFO 03-07 09:40:35 llm_engine.py:436] init engine (profile, create kv cache, warmup model) took 60.26 seconds
# tokenizer_config.json:   0%|          | 0.00/55.5k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# Unsloth 2025.3.8 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %% [markdown]
# ### Data Prep
# <a name="Data"></a>
#
# We directly leverage [@willccbb](https://gist.github.com/willccbb/4676755236bb08cab5f4e54a0475d6fb) for data prep and all reward functions. You are free to create your own!

# %%
import re
from datasets import load_dataset, Dataset

# Load and prep dataset
SYSTEM_PROMPT = """
Respond in the following format:
<reasoning>
...
</reasoning>
<answer>
...
</answer>
"""

XML_COT_FORMAT = """\
<reasoning>
{reasoning}
</reasoning>
<answer>
{answer}
</answer>
"""

def extract_xml_answer(text: str) -> str:
    answer = text.split("<answer>")[-1]
    answer = answer.split("</answer>")[0]
    return answer.strip()

def extract_hash_answer(text: str) -> str | None:
    if "####" not in text:
        return None
    return text.split("####")[1].strip()

# uncomment middle messages for 1-shot prompting
def get_gsm8k_questions(split = "train") -> Dataset:
    data = load_dataset('openai/gsm8k', 'main')[split] # type: ignore
    data = data.map(lambda x: { # type: ignore
        'prompt': [
            {'role': 'system', 'content': SYSTEM_PROMPT},
            {'role': 'user', 'content': x['question']}
        ],
        'answer': extract_hash_answer(x['answer'])
    }) # type: ignore
    return data # type: ignore

dataset = get_gsm8k_questions()

# Reward functions
def correctness_reward_func(prompts, completions, answer, **kwargs) -> list[float]:
    responses = [completion[0]['content'] for completion in completions]
    q = prompts[0][-1]['content']
    extracted_responses = [extract_xml_answer(r) for r in responses]
    print('-'*20, f"Question:\n{q}", f"\nAnswer:\n{answer[0]}", f"\nResponse:\n{responses[0]}", f"\nExtracted:\n{extracted_responses[0]}")
    return [2.0 if r == a else 0.0 for r, a in zip(extracted_responses, answer)]

def int_reward_func(completions, **kwargs) -> list[float]:
    responses = [completion[0]['content'] for completion in completions]
    extracted_responses = [extract_xml_answer(r) for r in responses]
    return [0.5 if r.isdigit() else 0.0 for r in extracted_responses]

def strict_format_reward_func(completions, **kwargs) -> list[float]:
    """Reward function that checks if the completion has a specific format."""
    pattern = r"^<reasoning>\n.*?\n</reasoning>\n<answer>\n.*?\n</answer>\n$"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    return [0.5 if match else 0.0 for match in matches]

def soft_format_reward_func(completions, **kwargs) -> list[float]:
    """Reward function that checks if the completion has a specific format."""
    pattern = r"<reasoning>.*?</reasoning>\s*<answer>.*?</answer>"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    return [0.5 if match else 0.0 for match in matches]

def count_xml(text) -> float:
    count = 0.0
    if text.count("<reasoning>\n") == 1:
        count += 0.125
    if text.count("\n</reasoning>\n") == 1:
        count += 0.125
    if text.count("\n<answer>\n") == 1:
        count += 0.125
        count -= len(text.split("\n</answer>\n")[-1])*0.001
    if text.count("\n</answer>") == 1:
        count += 0.125
        count -= (len(text.split("\n</answer>")[-1]) - 1)*0.001
    return count

def xmlcount_reward_func(completions, **kwargs) -> list[float]:
    contents = [completion[0]["content"] for completion in completions]
    return [count_xml(c) for c in contents]
# Out:
# README.md:   0%|          | 0.00/7.94k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/2.31M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/419k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/7473 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1319 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7473 [00:00<?, ? examples/s]

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
#
# Now set up GRPO Trainer and all configurations!

# %%
max_prompt_length = 256

from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    learning_rate = 5e-6,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.1,
    warmup_ratio = 0.1,
    lr_scheduler_type = "cosine",
    optim = "paged_adamw_8bit",
    logging_steps = 1,
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 1, # Increase to 4 for smoother training
    num_generations = 6, # Decrease if out of memory
    max_prompt_length = max_prompt_length,
    max_completion_length = max_seq_length - max_prompt_length,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps = 250,
    save_steps = 250,
    max_grad_norm = 0.1,
    report_to = "none", # Can use Weights & Biases
    output_dir = "outputs",
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 6

# %% [markdown]
# And let's run the trainer! If you scroll up, you'll see a table of rewards. The goal is to see the `reward` column increase!
#
# You might have to wait 150 to 200 steps for any action. You'll probably get 0 reward for the first 100 steps. Please be patient!
#
# | Step | Training Loss | reward    | reward_std | completion_length | kl       |
# |------|---------------|-----------|------------|-------------------|----------|
# | 1    | 0.000000      | 0.125000  | 0.000000   | 200.000000        | 0.000000 |
# | 2    | 0.000000      | 0.072375  | 0.248112   | 200.000000        | 0.000000 |
# | 3    | 0.000000      | -0.079000 | 0.163776   | 182.500000        | 0.000005 |

# %%
trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [
        xmlcount_reward_func,
        soft_format_reward_func,
        strict_format_reward_func,
        int_reward_func,
        correctness_reward_func,
    ],
    args = training_args,
    train_dataset = dataset,
)
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 56 | Num Epochs = 5 | Total steps = 250
# O^O/ \_/ \    Batch size per device = 6 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (6 x 1 x 1) = 6
#  "-____-"     Trainable parameters = 83,886,080/8,000,000,000 (1.05% trained)
# -------------------- Question:
# Please analyze the following email content.
# Determine if this email is likely a phishing attempt and if so provide the Phishing type
#
# Email to Analyze:
# Headers: Subject: Cybersecurity Update
# Body:
# Dear user,
#
# We’re enhancing cybersecurity. All employees must **update their account credentials**.
#
# Steps:
# 1. Click here to go to the security update portal.
# 2. Follow instructions to create a new login.
# 3. Choose a strong password.
#
# Complete by Friday to avoid access issues.
#
# Best regards,
# IT Support Team
# *System-generated message, do not reply.*
# Answer:
# CredentialHarvesting
# Response:
# </reasoning>
# The email appears to be a phishing attempt. Here's why:
#
# 1. **Lack of personalized greeting**: The email addresses the recipient as "user" instead of their actual username or name, which is a common trait of phishing emails as they are often sent to a large number of recipients without personalization.
#
# 2. **Sense of urgency**: The email creates a false sense of urgency by stating that the update must be completed by Friday, which is an attempt to prompt the recipient into acting impulsively without verifying the authenticity of the email.
#
# 3. **Direct link to an unspecified portal**: The email instructs the recipient to click on a link without specifying the URL, which can lead to a phishing website or a malware download.
#
# 4. **Request to create a new login and password**: The email asks the recipient to create a new login and password, which can compromise existing account credentials and potentially lead to account takeover.
#
# 5. **No clear indication of the update's purpose or benefits**: The email does not explain why the update is necessary, making it unclear what the update aims to accomplish.
#
# 6. **"System-generated message, do not reply"**: This is a typical phrase used by actual system-generated emails, but it can be a red flag as it may indicate that the email is indeed an automated phishing attempt, and the sender is trying to avoid receiving responses that could expose the phishing attempt.
#
# </answer>
# Phishing type: **Spear phishing (tailored for employees)**
# Extracted:
# </reasoning>
# The email appears to be a phishing attempt. Here's why:
#
# 1. **Lack of personalized greeting**: The email addresses the recipient as "user" instead of their actual username or name, which is a common trait of phishing emails as they are often sent to a large number of recipients without personalization.
#
# 2. **Sense of urgency**: The email creates a false sense of urgency by stating that the update must be completed by Friday, which is an attempt to prompt the recipient into acting impulsively without verifying the authenticity of the email.
#
# 3. **Direct link to an unspecified portal**: The email instructs the recipient to click on a link without specifying the URL, which can lead to a phishing website or a malware download.
#
# 4. **Request to create a new login and password**: The email asks the recipient to create a new login and password, which can compromise existing account credentials and potentially lead to account takeover.
#
# 5. **No clear indication of the update's purpose or benefits**: The email does not explain why the update is necessary, making it unclear what the update aims to accomplish.
#
# 6. **"System-generated message, do not reply"**: This is a typical phrase used by actual system-generated emails, but it can be a red flag as it may indicate that the email is indeed an automated phishing attempt, and the sender is trying to avoid receiving responses that could expose the phishing attempt.
#     <div>
#
#       <progress value='40' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 40/250 51:47 < 4:46:14, 0.01 it/s, Epoch 0.70/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completion_length</th>
#       <th>kl</th>
#       <th>rewards / xmlcount_reward_func</th>
#       <th>rewards / soft_format_reward_func</th>
#       <th>rewards / strict_format_reward_func</th>
#       <th>rewards / int_reward_func</th>
#       <th>rewards / correctness_reward_func</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>-0.559500</td>
#       <td>0.919820</td>
#       <td>317.500000</td>
#       <td>0.000000</td>
#       <td>-0.559500</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>-0.000000</td>
#       <td>-0.618667</td>
#       <td>0.821644</td>
#       <td>324.000000</td>
#       <td>0.000000</td>
#       <td>-0.618667</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>-0.949833</td>
#       <td>0.205947</td>
#       <td>255.500000</td>
#       <td>0.000010</td>
#       <td>-0.949833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>-0.209500</td>
#       <td>0.577929</td>
#       <td>280.166687</td>
#       <td>0.000011</td>
#       <td>-0.209500</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>-0.926333</td>
#       <td>0.338566</td>
#       <td>261.500000</td>
#       <td>0.000010</td>
#       <td>-0.926333</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>-0.690000</td>
#       <td>0.808791</td>
#       <td>309.500000</td>
#       <td>0.000010</td>
#       <td>-0.690000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>-0.552167</td>
#       <td>0.647574</td>
#       <td>291.166687</td>
#       <td>0.000010</td>
#       <td>-0.552167</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>-0.619833</td>
#       <td>0.670701</td>
#       <td>256.500000</td>
#       <td>0.000010</td>
#       <td>-0.619833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>-0.254500</td>
#       <td>0.554046</td>
#       <td>191.333344</td>
#       <td>0.000011</td>
#       <td>-0.254500</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>-0.292333</td>
#       <td>0.520116</td>
#       <td>262.666687</td>
#       <td>0.000012</td>
#       <td>-0.292333</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>-0.622833</td>
#       <td>0.668573</td>
#       <td>254.000000</td>
#       <td>0.000017</td>
#       <td>-0.622833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>-0.383833</td>
#       <td>0.850628</td>
#       <td>288.833344</td>
#       <td>0.000015</td>
#       <td>-0.383833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>-0.302333</td>
#       <td>0.468456</td>
#       <td>227.833344</td>
#       <td>0.000025</td>
#       <td>-0.302333</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>-0.346333</td>
#       <td>0.646896</td>
#       <td>284.333344</td>
#       <td>0.000027</td>
#       <td>-0.346333</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000000</td>
#       <td>-0.502833</td>
#       <td>0.419934</td>
#       <td>218.833344</td>
#       <td>0.000020</td>
#       <td>-0.502833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000000</td>
#       <td>-0.156167</td>
#       <td>0.450532</td>
#       <td>265.500000</td>
#       <td>0.000044</td>
#       <td>-0.156167</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.000000</td>
#       <td>-0.232500</td>
#       <td>0.654711</td>
#       <td>252.166672</td>
#       <td>0.000056</td>
#       <td>-0.232500</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.000000</td>
#       <td>-0.987833</td>
#       <td>0.228142</td>
#       <td>262.333344</td>
#       <td>0.000065</td>
#       <td>-0.987833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.000000</td>
#       <td>-0.763000</td>
#       <td>0.653785</td>
#       <td>280.833344</td>
#       <td>0.000089</td>
#       <td>-0.763000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000000</td>
#       <td>-0.466833</td>
#       <td>0.745677</td>
#       <td>293.333344</td>
#       <td>0.000082</td>
#       <td>-0.466833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.000000</td>
#       <td>-0.252500</td>
#       <td>0.523524</td>
#       <td>226.333344</td>
#       <td>0.000418</td>
#       <td>-0.252500</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.000000</td>
#       <td>-0.312000</td>
#       <td>0.573108</td>
#       <td>273.666687</td>
#       <td>0.000238</td>
#       <td>-0.312000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.000000</td>
#       <td>-0.345333</td>
#       <td>0.588057</td>
#       <td>226.500000</td>
#       <td>0.000717</td>
#       <td>-0.345333</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.000000</td>
#       <td>-0.157500</td>
#       <td>0.453923</td>
#       <td>266.333344</td>
#       <td>0.000943</td>
#       <td>-0.157500</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.000000</td>
#       <td>-0.676667</td>
#       <td>0.714077</td>
#       <td>284.500000</td>
#       <td>0.000789</td>
#       <td>-0.676667</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.000100</td>
#       <td>0.003333</td>
#       <td>0.008165</td>
#       <td>242.333344</td>
#       <td>0.002017</td>
#       <td>0.003333</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
# -------------------- Question:
# Please analyze the following email content.
# Determine if this email is likely a phishing attempt and if so provide the Phishing type
#
# Email to Analyze:
# Headers: Subject: Suspicious PayPal Bitcoin Activity (Fake Alert)
# Body:
# We detected a $599 Bitcoin purchase via PayPal from Texas. **Suspended for your protection**.
#
# If unauthorized, call **(888) XXX-XXXX** or log in to verify.
#
# Transaction: BTC $599…
#
# Regards,
# PayPal Security
# Answer:
# Vishing/CredentialHarvesting
# Response:
# <reasoning>
# The email appears to be a phishing attempt due to several red flags. The email is attempting to create a sense of urgency and panic by stating that a suspicious activity has been detected, which may lead the recipient to quickly call a phone number without verifying the authenticity of the email. The email is vague about the details of the alleged transaction, only mentioning the amount and the fact that it was made in Texas, which could be done to gauge the recipient's curiosity and increase the likelihood of responding. Additionally, the email does not contain any personalized information, which is unusual for a legitimate PayPal notification. Furthermore, the email contains a clear call-to-action, which is a common tactic used by scammers to trick users into divulging sensitive information or providing financial details.
# </reasoning>
# <Known Phishing Type:
# This email is classified as a 'Spear Phishing' attempt, although it could also be classified as a 'Vishing' attempt due to the mention of a phone number.
#
# Explanation of 'Spear Phishing':
# Spear phishing is a type of targeted phishing attack, where the attacker usually includes some personal information in the phishing email, like the recipient's name, company or organization, to make it appear authentic. In this case, the message lacks personalized information that would make it seem like a'spear phishing'. The recipient's location is given however which is the Texas area, but you cannot verify if it was meant to be an actual location.
#
# Explanation of 'Vishing':
# Vishing, or voice phishing, is a phishing technique that involves scammers using voice calls or phone calls to spear phish or for phishing. The mention of calling the given number to verify the transaction makes this email to possibly also be a vishing attempt, in close conjunction with phishing.
# Extracted:
# <reasoning>
# The email appears to be a phishing attempt due to several red flags. The email is attempting to create a sense of urgency and panic by stating that a suspicious activity has been detected, which may lead the recipient to quickly call a phone number without verifying the authenticity of the email. The email is vague about the details of the alleged transaction, only mentioning the amount and the fact that it was made in Texas, which could be done to gauge the recipient's curiosity and increase the likelihood of responding. Additionally, the email does not contain any personalized information, which is unusual for a legitimate PayPal notification. Furthermore, the email contains a clear call-to-action, which is a common tactic used by scammers to trick users into divulging sensitive information or providing financial details.
# </reasoning>
# <Known Phishing Type:
# This email is classified as a 'Spear Phishing' attempt, although it could also be classified as a 'Vishing' attempt due to the mention of a phone number.
#
# Explanation of 'Spear Phishing':
# Spear phishing is a type of targeted phishing attack, where the attacker usually includes some personal information in the phishing email, like the recipient's name, company or organization, to make it appear authentic. In this case, the message lacks personalized information that would make it seem like a'spear phishing'. The recipient's location is given however which is the Texas area, but you cannot verify if it was meant to be an actual location.
#
# Explanation of 'Vishing':
# Vishing, or voice phishing, is a phishing technique that involves scammers using voice calls or phone calls to spear phish or for phishing. The mention of calling the given number to verify the transaction makes this email to possibly also be a vishing attempt, in close conjunction with phishing.
# Unsloth: Will smartly offload gradients to save VRAM!
# -------------------- Question:
# Please analyze the following email content.
# Determine if this email is likely a phishing attempt and if so provide the Phishing type
#
# Email to Analyze:
# Headers: Subject: Document shared with you: "Important Staff Meeting.docx"
# Body:
# {User} shared a document: **Important Staff Meeting.docx**
#
# Open [link]
#
# Google LLC… You received this email because a file was shared with you.
# Answer:
# CredentialHarvesting/MalwareDelivery
# Response:
# <analyzing the email>
# The email appears to be a phishing attempt because it does not match the behavior of a standard file sharing notification from Google.
#
# Standard Google Drive notifications usually provide a link to the file in Google Drive or a button to see the file, but the link in the email points to the root domain "google.com" instead of "googledrive.com" or a similar subdomain which would indicate that the link may be misleading.
#
# Additionally, the fact that the link is in a format ([link]) without any additional information or a sender's name, makes it seem suspicious.
# </analyzing the email>
#
# <answer>
# The email is likely a phishing attempt, specifically a type of phishing known as a "Spear Phishing" where a file sharing notification is used to trick users into opening a malicious link.
# Extracted:
# The email is likely a phishing attempt, specifically a type of phishing known as a "Spear Phishing" where a file sharing notification is used to trick users into opening a malicious link.
# -------------------- Question:
# Please analyze the following email content.
# Determine if this email is likely a phishing attempt and if so provide the Phishing type
#
# Email to Analyze:
# Headers: Subject: Review Emails – [Date]
# Body:
# As of [recent date/time], **13 messages** are awaiting your action.
#
# Visit [link] to release them to your inbox.
#
# Thank you,
# IT Support
# Answer:
# CredentialHarvesting
# Response:
# <reasoning>
# The email appears to be a suspicious communication. The following factors are indications that this might be a phishing attempt:
# - The email does not specify the user's name or any personal details, which is unprofessional and unusual in a legitimate corporate communication.
# - There's no contextual information about what these 13 messages are or why they are being held for action.
# - The link to view the messages is provided without any additional information, which may redirect the recipient to a malicious site or open a security risk.
# - The email is brief and lacks a sense of authority or legitimacy through brand recognition or additional details that would be expected in a corporate email.
# </reasoning>
# <answer>
# This email is likely a phishing attempt of the type "Generic Phishing" or "Abandoned Asset Scam" type. The primary goal is to get the recipient to click the link, potentially compromising their login credentials or installing malware on their device. However, the presence of the link and the brevity of the message make it a more prominent threat of a "Spear Multilink" phishing attack since it asks for immediate action.
# Extracted:
# This email is likely a phishing attempt of the type "Generic Phishing" or "Abandoned Asset Scam" type. The primary goal is to get the recipient to click the link, potentially compromising their login credentials or installing malware on their device. However, the presence of the link and the brevity of the message make it a more prominent threat of a "Spear Multilink" phishing attack since it asks for immediate action.
# -------------------- Question:
# Please analyze the following email content.
# Determine if this email is likely a phishing attempt and if so provide the Phishing type
#
# Email to Analyze:
# Headers: Subject: Job Opportunity
# Body:
# I am sharing job opportunity information... Part-Time UNICEF job... weekly pay of $500.00 USD... If interested, kindly contact via [personal email] with your alternate non-educational email address (Gmail, Yahoo, Hotmail, etc.) for details of employment.
#
# Regards,
# Job Opportunity
# Answer:
# JobScam/DataHarvesting
# Response:
# <reasoning>
# The email appears to be a phishing attempt. Here's why:
#
# 1. **Lack of official UNICEF contact information**: A legitimate UNICEF job posting would typically include official contact information such as an official UNICEF email address, phone number, or a website. The email's tone and content do not indicate any attempt to use official UNICEF channels.
#
# 2. **Request for alternate email address**: The sender asks the recipient to contact them via a non-educational email address, which could be unsecured. This could be a way to collect personal email addresses, potentially for future phishing or spamming attempts.
#
# 3. **Urgency and lack of details**: The email does not provide any information about the job requirements, location, or the hiring process. This could be an attempt to create a sense of urgency and persuade the recipient into acting without thoroughly considering the opportunity.
#
# 4. **Poor grammar and formatting**: The email's tone and formatting lack professionalism, which is uncommon for a legitimate job posting.
#
# 5. **No reference to a company website or social media**: Legitimate job postings usually include references to the company's official website or social media handles to verify the authenticity of the job posting.
#
# </reasoning>
# <answer>
# The email is likely a phishing attempt, and it appears to be a type of **Low-Level Phishing** or **Social Engineering** attempt. This type of phishing usually involves a simple, unsophisticated approach with the goal of collecting sensitive information or spreading malware.
# Extracted:
# The email is likely a phishing attempt, and it appears to be a type of **Low-Level Phishing** or **Social Engineering** attempt. This type of phishing usually involves a simple, unsophisticated approach with the goal of collecting sensitive information or spreading malware.
# -------------------- Question:
# Please analyze the following email content.
# Determine if this email is likely a phishing attempt and if so provide the Phishing type
#
# Email to Analyze:
# Headers: Subject: [Importante] Su cuenta ha sido limitada temporalmente (Your account has been temporarily limited)
# Body:
# Re: [Importante] - Su cuenta ha sido limitada temporalmente.
#
# Tu cuenta ha sido limitada hasta que tengamos noticias tuyas. Mientras esté limitada, algunas opciones no estarán disponibles...
# Answer:
# CredentialHarvesting
# Response:
# </reasoning>
# El contenido del correo electrónico puede ser una posible tentativa de phishing debido a los siguientes indicadores:
#
# *   La bandera "Importante" que utilizan es común en correos electrónicos fraudulentos para llamar la atención del destinatario.
# *   La suposición de que la cuenta está limitada sin proporcionar información específica sobre la causa real del cisma es sospechosa.
# *   Faltan detalles reales sobre la acción que se va a tomar o como recuperar la cuenta.
#
# Esta podría ser una tentativa de phishing tipo "Urgente/Verificación de identidad" donde se intenta separar al usuario de su cuenta y/o información sensible proporcionando una sensación de urgencia.
# </answer>
#
# Advertencia: Si en algún momento recibes un correo similar es importante no hacer clic en enlaces ni proporcionar información personaliteITS }}
# Extracted:
# </reasoning>
# El contenido del correo electrónico puede ser una posible tentativa de phishing debido a los siguientes indicadores:
#
# *   La bandera "Importante" que utilizan es común en correos electrónicos fraudulentos para llamar la atención del destinatario.
# *   La suposición de que la cuenta está limitada sin proporcionar información específica sobre la causa real del cisma es sospechosa.
# *   Faltan detalles reales sobre la acción que se va a tomar o como recuperar la cuenta.
#
# Esta podría ser una tentativa de phishing tipo "Urgente/Verificación de identidad" donde se intenta separar al usuario de su cuenta y/o información sensible proporcionando una sensación de urgencia.
# -------------------- Question:
# Please analyze the following email content.
# Determine if this email is likely a phishing attempt and if so provide the Phishing type
#
# Email to Analyze:
# Headers: Subject: Student Job Opening
# From: Dr. [Name] <redacted@gmail.com>
# Body:
# From: P***** C***** <redacted@gmail.com>
# Subject: Student Job Opening
#
# The service of a student is urgently required as a remote administrative assistant in the Biology Dept., **$320 weekly** for 8 hours/week.
#
# To apply, submit your resume via this email.
#
# Sincerely,
# Dr. [Name]
# Professor, Dept. of Biology
# Answer:
# JobScam/DataHarvesting
# Response:
# <reasoning>
# The email appears to be a phishing attempt because it contains several red flags.
#
# Firstly, the email is asking for a sensitive action (submitting a resume) in response to an unsolicited message. Legitimate job openings would typically be advertised through the university's official channels, and the hiring process would involve more formal proceedings.
#
# Secondly, the email does not mention the university's name, department's name, or the professor's actual name, which is often seen in phishing attempts to create a sense of legitimacy.
#
# Thirdly, the offer is surprisingly good ($320 weekly for 8 hours/week) and lacks any kind of specificity or requirements that might be expected in a legitimate job posting.
#
# Lastly, the email requests a resume submission via the sender's email, which could be a trick to collect resumes for potential spam or other malicious purposes.
#
# </reasoning>
# <answer>
# This email is likely a phishing attempt and can be classified as a "Job Scam" or "Work-From-Home Scam".
# Extracted:
# This email is likely a phishing attempt and can be classified as a "Job Scam" or "Work-From-Home Scam".
# -------------------- Question:
# Please analyze the following email content.
# Determine if this email is likely a phishing attempt and if so provide the Phishing type
#
# Email to Analyze:
# Headers: Subject: Grant Service! (Free Money Offer)
# Body:
# **Grant Service!**
#
# We have a new grant service that gives students $1,000 for educational expenses. **Apply now by clicking the link** and filling out the form.
#
# Best,
# Grants Department
# Answer:
# GrantScam/DataHarvesting/Advance−FeeFraud
# Response:
# <Analysis>
# This email appears to be a phishing attempt because it uses several tactics commonly used by scammers.
#
# Firstly, the subject line and the body of the email use all capital letters, which can grab the attention of the recipient and make them more likely to open the email.
#
# Secondly, the email creates a sense of urgency by using the phrase "Apply now" which can be a tactic to prompt the recipient into acting impulsively without thinking thoroughly.
#
# Thirdly, the link in the email is not provided, making it difficult for the recipient to verify if the link is legitimate or malicious.
#
# Lastly, the email claims that the recipient can get $1,000 for "educational expenses" without any conditions or requirements, which seems too good to be true.
#
# The phishing type of this email is a type of **Scareware phishing** or **Urgency phishing** attack. The email is designed to make the recipient feel like they are missing out on a great opportunity and force them to click on the link without verifying its legitimacy.
# </Analysis>
# <answer>
# Yes, this email is likely a phishing attempt.
# Extracted:
# Yes, this email is likely a phishing attempt.
# -------------------- Question:
# Please analyze the following email content.
# Determine if this email is likely a phishing attempt and if so provide the Phishing type
#
# Email to Analyze:
# Headers: Subject: Program Analyst Opening – Apply Now
# Body:
# Admin & Program Analyst Opening – part-time, remote.
#
# Please provide contact details to receive an application.
#
# Thank you.
# Answer:
# JobScam/DataHarvesting
# Response:
# <analyzing the email content>
#
# The email appears to be a phishing attempt.
#
# Reasoning:
# - The email lacks company branding and context, making it unclear who the sender is and what the position is for.
# - The email asks for "contact details" to receive an application, which may be an attempt to gather sensitive information such as email addresses or other contact information.
# - There is no genuine application process mentioned, which would typically involve a link to a company website or a specific job portal.
# - The email does not provide any information about the company or the position, which could make it seem suspicious.
#
# </analyzing the email content>
#
# <phishing type: Vishing (Voice Phishing) / General Phishing>
#
# This email can be classified as a "Vishing / General Phishing" attempt because it is a basic phishing attempt that may be preparatory to a further contact, such as a voice call, where the scammer will ask for the recipient's contact information or other sensitive details.
# Extracted:
# <analyzing the email content>
#
# The email appears to be a phishing attempt.
#
# Reasoning:
# - The email lacks company branding and context, making it unclear who the sender is and what the position is for.
# - The email asks for "contact details" to receive an application, which may be an attempt to gather sensitive information such as email addresses or other contact information.
# - There is no genuine application process mentioned, which would typically involve a link to a company website or a specific job portal.
# - The email does not provide any information about the company or the position, which could make it seem suspicious.
#
# </analyzing the email content>
#
# <phishing type: Vishing (Voice Phishing) / General Phishing>
#
# This email can be classified as a "Vishing / General Phishing" attempt because it is a basic phishing attempt that may be preparatory to a further contact, such as a voice call, where the scammer will ask for the recipient's contact information or other sensitive details.
# -------------------- Question:
# Please analyze the following email content.
# Determine if this email is likely a phishing attempt and if so provide the Phishing type
#
# Email to Analyze:
# Headers: Subject: Norton Subscription Renewal
# Body:
# Dear User,
#
# Your “Norton” subscription worth USD $321.68 **renewed successfully**.
#
# If you did not authorize this, or wish to cancel, you can cancel within 12 hours of purchase. **Please contact us at {phone number}**.
#
# Thank you,
# Billing Dept.
# Answer:
# Vishing/FinancialFraud/TechSupportScam
# Response:
# </reasoning>
# The email has several characteristics that are typical of a phishing attempt:
#
# 1. **Lack of proper subscription notification:** Legitimate subscription renewal notifications from a company like Norton would usually include a lot more details, such as a subscription ID, the type of subscription, and the details of the payment method. This lack of information makes the email suspicious.
# 2. **Urgent tone and time constraint:** The request to cancel within 12 hours creates a sense of urgency, which can cause the recipient to act impulsively and not think carefully about the authenticity of the email. This is a common phishing tactic.
# 3. **Generic message with no personalization:** The email does not address the recipient by their actual name, which is unusual for a company like Norton that typically personalizes its communication.
# 4. **Suspicious formatting:** The use of asterisks around the word "renewed successfully" and "Please contact us" seems unnecessary and could be an attempt to create the impression that the text is being highlighted.
# 5. **Suspicious contact information:** The use of a phone number instead of a more secure contact method, like a website or email address, increases the risk of this being a phishing attempt.
# 6. **Missing subscription details:** Norton would usually provide more details about the subscription in the notification, such as the subscription type (e.g., Norton 360), the subscription period, and the payment method.
#
# </answer>
# This email is likely a phishing attempt, and the type of phishing is **Phishing with a spoofed notification:** This type of phishing aims to create a false sense of urgency and trick the recipient into taking a specific action (in this case, calling a suspicious phone number).
# Extracted:
# </reasoning>
# The email has several characteristics that are typical of a phishing attempt:
#
# 1. **Lack of proper subscription notification:** Legitimate subscription renewal notifications from a company like Norton would usually include a lot more details, such as a subscription ID, the type of subscription, and the details of the payment method. This lack of information makes the email suspicious.
# 2. **Urgent tone and time constraint:** The request to cancel within 12 hours creates a sense of urgency, which can cause the recipient to act impulsively and not think carefully about the authenticity of the email. This is a common phishing tactic.
# 3. **Generic message with no personalization:** The email does not address the recipient by their actual name, which is unusual for a company like Norton that typically personalizes its communication.
# 4. **Suspicious formatting:** The use of asterisks around the word "renewed successfully" and "Please contact us" seems unnecessary and could be an attempt to create the impression that the text is being highlighted.
# 5. **Suspicious contact information:** The use of a phone number instead of a more secure contact method, like a website or email address, increases the risk of this being a phishing attempt.
# 6. **Missing subscription details:** Norton would usually provide more details about the subscription in the notification, such as the subscription type (e.g., Norton 360), the subscription period, and the payment method.
# -------------------- Question:
# Please analyze the following email content.
# Determine if this email is likely a phishing attempt and if so provide the Phishing type
#
# Email to Analyze:
# Headers: Subject: Research Assistant Position
# From: CAMPUS JOBS <redacted@gmail.com>
# Body:
# From: CAMPUS JOBS <redacted@gmail.com>
# Subject: Research Assistant Position
#
# ... Undergrad/Grad Research Assistant, ~6-7 hours/week for **$350 weekly**, remote.
#
# (Details of duties...)
#
# To proceed, submit your resume, phone number, and year of study via this email ([redacted]@mail.com).
#
# Best regards,
# (he/him)
# [Fake Name]
# Address
# https://www.uvic.ca/
# Answer:
# JobScam/DataHarvesting
# Response:
# <Red Flags>
# The email is most likely a phishing attempt for several reasons:
#
# - The sender's email address, redacted@gmail.com, does not match the domain provided at the bottom of the email (https://www.uvic.ca). A legitimate organization would typically have a official email address with their own domain.
# - The email asks for a personal contact information (phone number) which could be used for further scams or phishing.
# - The email lacks any official credentials or a direct link to an official website of the university, which would typically be the case for a legitimate job posting.
# - The request to submit personal and university-related information via a non-official email address increases the likelihood of a phishing attempt.
# - The salary offered $350 weekly is relatively high for a part-time research assistant position, especially considering it's only for 6-7 hours per week.
# </Red Flags>
#
# <Phishing Type>
# This email is a type of phishing attempt known as a "Job Scam" or "Work-From-Home Scam."
# Extracted:
# <Red Flags>
# The email is most likely a phishing attempt for several reasons:
#
# - The sender's email address, redacted@gmail.com, does not match the domain provided at the bottom of the email (https://www.uvic.ca). A legitimate organization would typically have a official email address with their own domain.
# - The email asks for a personal contact information (phone number) which could be used for further scams or phishing.
# - The email lacks any official credentials or a direct link to an official website of the university, which would typically be the case for a legitimate job posting.
# - The request to submit personal and university-related information via a non-official email address increases the likelihood of a phishing attempt.
# - The salary offered $350 weekly is relatively high for a part-time research assistant position, especially considering it's only for 6-7 hours per week.
# </Red Flags>
#
# <Phishing Type>
# This email is a type of phishing attempt known as a "Job Scam" or "Work-From-Home Scam."
# -------------------- Question:
# Please analyze the following email content.
# Determine if this email is likely a phishing attempt and if so provide the Phishing type
#
# Email to Analyze:
# Headers: Subject: Approved: Student Grant (No Repayment)
# Body:
# Dear Student,
#
# You’ve been approved for a **$4,700 grant** (no repayment). To claim:
# Email Officer at [Outlook.com] from your **personal email** with:
# - Full Name
# - School
# - Phone
# - Personal Email
#
# (Do not reply from your school email. Only 100 will be granted.)
#
# Regards,
# Canada Student Grant Program
# Answer:
# GrantScam/DataHarvesting/FinancialFraud
# Response:
# <Reasoning>
# The email appears to be a phishing attempt due to several red flags.
#
# 1. **Lack of personalization**: The email does not address the recipient by their name, which is unusual for an official communication from a government agency.
# 2. **Poor grammar and formatting**: The email contains typos and inconsistent formatting, which is uncommon in official communication.
# 3. **Urgency and artificial scarcity**: The email creates a sense of urgency by stating that only 100 grants will be awarded, which may prompt the recipient to act hastily without verifying the offer.
# 4. **Request for sensitive information**: The email asks the recipient to share their personal email address, phone number, and other identifying information via a third-party email service (Outlook.com), which increases the risk of data compromise.
# 5. **Missing official contact information**: Official government agencies typically include their official email addresses, websites, or contact numbers in their communications.
# 6. **Suspicious sender**: The email comes from a generic email address (Reguards, note: 'Regards') and an ambiguous 'Canada Student Grant Program', which lacks clarity and authenticity.
#
# </Reasoning>
# <Answer>
# This email is likely a phishing attempt, and it falls under the category of a **'Grant or Financial Assistance Phishing'**.
# Extracted:
# <Reasoning>
# The email appears to be a phishing attempt due to several red flags.
#
# 1. **Lack of personalization**: The email does not address the recipient by their name, which is unusual for an official communication from a government agency.
# 2. **Poor grammar and formatting**: The email contains typos and inconsistent formatting, which is uncommon in official communication.
# 3. **Urgency and artificial scarcity**: The email creates a sense of urgency by stating that only 100 grants will be awarded, which may prompt the recipient to act hastily without verifying the offer.
# 4. **Request for sensitive information**: The email asks the recipient to share their personal email address, phone number, and other identifying information via a third-party email service (Outlook.com), which increases the risk of data compromise.
# 5. **Missing official contact information**: Official government agencies typically include their official email addresses, websites, or contact numbers in their communications.
# 6. **Suspicious sender**: The email comes from a generic email address (Reguards, note: 'Regards') and an ambiguous 'Canada Student Grant Program', which lacks clarity and authenticity.
#
# </Reasoning>
# <Answer>
# This email is likely a phishing attempt, and it falls under the category of a **'Grant or Financial Assistance Phishing'**.
# -------------------- Question:
# Please analyze the following email content.
# Determine if this email is likely a phishing attempt and if so provide the Phishing type
#
# Email to Analyze:
# Headers: Subject: Career Progression Program – Act Now
# Body:
# Enhance your career with our **Career Progression Program**. We provide financial aid and paid work-study opportunities.
#
# **Click here to register** for this exclusive program.
#
# Sincerely,
# Career Dev Team
# Answer:
# CredentialHarvesting/DataHarvesting
# Response:
# </reasoning>
# The email lacks essential information about the career progression program, such as what kind of job or industry it is related to or what kind of financial aid and work-study opportunities are provided. The email also uses a generic greeting and a vague expression "Act Now" which is a common tactic used by spammers to create a sense of urgency and prompt the recipient into making hasty decisions. Additionally, the request to "Click here to register" is risky as it may lead to a phishing website or a malware download. Furthermore, there is no verification of the sender's identity or an indication of how the recipient's information was obtained. </reasoning>
# <answer>
# The email bears characteristics of a phishing attempt, specifically of the type: Upsell or Ponzi Scheme. It appears to be an attempt to lure individuals into a program with promises of easy financial benefits without providing legitimate details or context, and instead encourages the recipients to act hastily without verifying the authenticity of the offer.
# Extracted:
# The email bears characteristics of a phishing attempt, specifically of the type: Upsell or Ponzi Scheme. It appears to be an attempt to lure individuals into a program with promises of easy financial benefits without providing legitimate details or context, and instead encourages the recipients to act hastily without verifying the authenticity of the offer.
# -------------------- Question:
# Please analyze the following email content.
# Determine if this email is likely a phishing attempt and if so provide the Phishing type
#
# Email to Analyze:
# Headers: Subject: UNESCO Work-From-Home Offer
# Body:
# **UNESCO Part-Time Job – $750/week** from home.
#
# Contact **Sarah at [Outlook.com]** to apply.
#
# (Work from home position.)
# Answer:
# JobScam/Advance−FeeFraud/DataHarvesting
# Response:
# **Phishing Analysis**
#
# The given email appears to be a phishing attempt. Here's why:
#
# 1. **Urgency and Lack of Personalization**: The email starts with a generic message that creates a sense of urgency and scarcity, trying to prompt the recipient into acting quickly without thoroughly considering the opportunity.
#
# 2. **Lack of Details**: The email is vague about the job requirements, duties, and qualifications needed for the position. Legitimate job postings usually provide detailed information about the position.
#
# 3. **Red Flag - Missing Domain**: The email mentions contacting Sarah at [Outlook.com], but it is generally recommended to use the recipient's organization's email domain for official communications and not a consumer-facing email service like Outlook.com.
#
# 4. **Generic Invitation**: The email does not have any authentication or official stamp from UNESCO, which is a well-established organization.
#
# 5. **Potential Entrapment**: The promise of a lucrative work-from-home position seems too good to be true and may be an attempt to entice recipients into revealing sensitive information.
#
# **Phishing Type:** This email can be classified as a type of **Social Engineering (Spear Phishing)** specifically **Baiting Phishing**. Baiting phishing involves sending legitimate-looking emails with enticing offers or fake job postings to lure recipients into divulging sensitive information.
# Extracted:
# **Phishing Analysis**
#
# The given email appears to be a phishing attempt. Here's why:
#
# 1. **Urgency and Lack of Personalization**: The email starts with a generic message that creates a sense of urgency and scarcity, trying to prompt the recipient into acting quickly without thoroughly considering the opportunity.
#
# 2. **Lack of Details**: The email is vague about the job requirements, duties, and qualifications needed for the position. Legitimate job postings usually provide detailed information about the position.
#
# 3. **Red Flag - Missing Domain**: The email mentions contacting Sarah at [Outlook.com], but it is generally recommended to use the recipient's organization's email domain for official communications and not a consumer-facing email service like Outlook.com.
#
# 4. **Generic Invitation**: The email does not have any authentication or official stamp from UNESCO, which is a well-established organization.
#
# 5. **Potential Entrapment**: The promise of a lucrative work-from-home position seems too good to be true and may be an attempt to entice recipients into revealing sensitive information.
#
# **Phishing Type:** This email can be classified as a type of **Social Engineering (Spear Phishing)** specifically **Baiting Phishing**. Baiting phishing involves sending legitimate-looking emails with enticing offers or fake job postings to lure recipients into divulging sensitive information.
# -------------------- Question:
# Please analyze the following email content.
# Determine if this email is likely a phishing attempt and if so provide the Phishing type
#
# Email to Analyze:
# Headers: Subject: Part-Time job
# From: [Compromised .gov Email]
# Body:
# From: [redacted]@gov.xx
# Subject: Part-Time job
#
# ... offering a UNESCO part-time remote job, **$750/week**. If interested, contact **Sarah at [redacted]@outlook.com** for details.
#
# N.B: strictly work from home.
# Answer:
# JobScam/Advance−FeeFraud/DataHarvesting
# Response:
# <reasoning>
# This email appears to be a phishing attempt because it exhibits several red flags commonly associated with phishing scams.
#
# 1.  The email is sent from a compromised government (.gov) email address, but the sender's email address ([redacted]@gov.xx and [redacted]@outlook.com) is not an official government email format. Genuine government emails typically have a more formal tone and would not be sent from an outlook email account.
# 2.  The offer appears too good to be true ( $750/week) and is significantly higher than what most part-time jobs pay. This heightened offer should raise suspicion.
# 3.  The email does not provide any further information about the job requirements, expectations, or company details, which is unusual for a job posting.
# 4.  The instruction to contact an external, personal email account ( [redacted]@outlook.com) rather than an official company email address or a contact form for inquiries is another red flag.
# 5.  The mention of "strictly work from home" without any further details may also be a tactic to gain the recipient's trust and make the offer sound legitimate.
#
# Considering these factors, this email can be classified as a:
#
# <answer>
# **Spear Phishing** type of phishing, which targets a specific individual or group with tailored, personalized messages.
# Extracted:
# **Spear Phishing** type of phishing, which targets a specific individual or group with tailored, personalized messages.
# -------------------- Question:
# Please analyze the following email content.
# Determine if this email is likely a phishing attempt and if so provide the Phishing type
#
# Email to Analyze:
# Headers: Subject: Final Settlement Agreement – Approved Today
# Body:
# Re: **Final Settlement Agreement Approved** – Please review and sign the attached document.
#
# (Attachment: Agreement.docx)
# Answer:
# MalwareDelivery/CredentialHarvesting
# Response:
# <reasoning>
# To determine if this email is a phishing attempt, let's analyze the characteristics of the email.
#
# The email appears to be a legitimate business communication, but it lacks critical details and red flags are present.
#
# 1. **Lack of Personalization**: The email doesn't address the recipient by their name, which is unusual for a formal settlement agreement.
# 2. **Informal Language**: The language used is quite casual, starting with "Please review and sign," which is not typical for a formal agreement document.
# ...
#
# Firstly, the subject line, "URGENT: W-2 Financial Report", is trying to create a sense of urgency which is a common tactic used to prompt the recipient into acting hastily without verifying the legitimacy of the request.
#
# Secondly, the email is missing a formal introduction, a clear context, and proper email format which are characteristics of a legitimate business or organizational email.
#
# Lastly, the user does not have the power to request something like this as they are an employee, as executive should have the IT department or HR to handle such requests.
#
# Phishing Type:
# </Reasoning>
# Spoofing - This is the act of mimicking a legitimate person or department. The email appears to be from an executive, but it could have actually originated from an external source (like a hacker).
# -------------------- Question:
# Please analyze the following email content.
# Determine if this email is likely a phishing attempt and if so provide the Phishing type
#
# Email to Analyze:
# Headers: Subject: Action Required: Microsoft Office 365 Premium Renewal
# Body:
# License requests in your organization:
#
# Message from Microsoft:
# Thanks for using Office 365 Premium! Please review the attached renewal details. If you want to cancel and avoid the USD $341.00 payment, call our Helpline at +1 (806) 544-4405.
#
# Product: Visio Plan 2
# Request date: 10/10/2024
# ...
# Answer:
# Vishing/FinancialFraud
# Response:
# <phishers' tactics observed>
# The email exhibits several characteristics of a phishing attempt:
# - It creates a sense of urgency by requesting an immediate action ("Action Required") and a deadline for cancelling the supposed payment ("avoid the USD $341.00 payment").
# - The email asks the recipient to call a helpline instead of directing them to log in to their Microsoft account or contacting official Microsoft support.
# - The email provides an 8-digit phone number (+1 806 544-4405), which could be an attempt to gain sensitive information over a non-verified communication channel.
# - No clear indication of the renewal process or the recipient's account information is given, which could make the recipient doubt the legitimacy of the notification.
# - There is no real-time update on their Microsoft 365 subscription.
# - The sender does not use the official Microsoft format and tone that they have come to expect from Microsoft communications.
# </phishers' tactics observed>
# <phishing type>
# The email is a type of phishing known as a "Bait and Hold" Phishing attack. This tactic created a false sense of urgency to prompt the recipient to contact the 'offered' support number rather than the 'usual' official customer service, exposing the recipient to the risk of losing sensitive information or financial data.
# Extracted:
# <phishers' tactics observed>
# The email exhibits several characteristics of a phishing attempt:
# - It creates a sense of urgency by requesting an immediate action ("Action Required") and a deadline for cancelling the supposed payment ("avoid the USD $341.00 payment").
# - The email asks the recipient to call a helpline instead of directing them to log in to their Microsoft account or contacting official Microsoft support.
# - The email provides an 8-digit phone number (+1 806 544-4405), which could be an attempt to gain sensitive information over a non-verified communication channel.
# - No clear indication of the renewal process or the recipient's account information is given, which could make the recipient doubt the legitimacy of the notification.
# - There is no real-time update on their Microsoft 365 subscription.
# - The sender does not use the official Microsoft format and tone that they have come to expect from Microsoft communications.
# </phishers' tactics observed>
# <phishing type>
# The email is a type of phishing known as a "Bait and Hold" Phishing attack. This tactic created a false sense of urgency to prompt the recipient to contact the 'offered' support number rather than the 'usual' official customer service, exposing the recipient to the risk of losing sensitive information or financial data.
# -------------------- Question:
# Please analyze the following email content.
# Determine if this email is likely a phishing attempt and if so provide the Phishing type
#
# Email to Analyze:
# Headers: Subject: CANVAS UPDATE
# Body:
# This is the last notification: we’ll stop processing incoming emails to your school account because you failed to verify your Microsoft 365 account, which may lead to permanent deletion in the next few hours.
#
# To **verify**, copy and paste the URL below into your browser (link redacted).
#
# Important Notice — Account disconnection will take place today.
#
# Thank You
# Microsoft@2024
# Answer:
# CredentialHarvesting
# Response:
# <Phishing Indicators>
#
# The email shows several characteristics of a phishing attempt:
#
# -   **Urgency**: The email creates a sense of urgency by stating that account processing will stop and the account may be deleted if the instructions are not followed immediately.
# -   **Threat**: The message threatens a consequence (permanent deletion of the account) if the recipient does not follow the instructions.
# -   **Lack of personalized information**: A legitimate email from Microsoft would typically address the user by their name and include specific details about their account.
# -   **Suspicious notification source**: The email is from "Microsoft@2024" which is a non-standard email address for Microsoft. Legitimate email from Microsoft typically use the full domain name "@microsoft.com".
# -   **Redacted link**: The link is redacted which raises suspicion as legitimate institutions would not hide their links to avoid such risks.
# -   **Poor grammar**: The email contains the phrase "Important Notice" which seems informal and non-standard, implying it might not be from the actual institution.
#
# </Phishing Indicators>
# Phishing Type: Spear Phishing or
# rovamentum (Generic Phishing Attempt), with an added element of  Accent Phishing to add to the urgency of the situation.
#
# This type of phishing is known as "rovamentum" (Generic Phishing) because it targets a large audience and doesn't contain any personalized information or details specific to the individual victim. The added element of "Accent Phishing" by adding a threat for a time-sensitive action amplifies the urgency, making the attempt more convincing.
# Extracted:
# <Phishing Indicators>
#
# The email shows several characteristics of a phishing attempt:
#
# -   **Urgency**: The email creates a sense of urgency by stating that account processing will stop and the account may be deleted if the instructions are not followed immediately.
# -   **Threat**: The message threatens a consequence (permanent deletion of the account) if the recipient does not follow the instructions.
# -   **Lack of personalized information**: A legitimate email from Microsoft would typically address the user by their name and include specific details about their account.
# -   **Suspicious notification source**: The email is from "Microsoft@2024" which is a non-standard email address for Microsoft. Legitimate email from Microsoft typically use the full domain name "@microsoft.com".
# -   **Redacted link**: The link is redacted which raises suspicion as legitimate institutions would not hide their links to avoid such risks.
# -   **Poor grammar**: The email contains the phrase "Important Notice" which seems informal and non-standard, implying it might not be from the actual institution.
#
# </Phishing Indicators>
# Phishing Type: Spear Phishing or
# rovamentum (Generic Phishing Attempt), with an added element of  Accent Phishing to add to the urgency of the situation.
#
# This type of phishing is known as "rovamentum" (Generic Phishing) because it targets a large audience and doesn't contain any personalized information or details specific to the individual victim. The added element of "Accent Phishing" by adding a threat for a time-sensitive action amplifies the urgency, making the attempt more convincing.
#     <div>
#
#       <progress value='41' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 41/250 53:19 < 4:45:46, 0.01 it/s, Epoch 0.71/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completion_length</th>
#       <th>kl</th>
#       <th>rewards / xmlcount_reward_func</th>
#       <th>rewards / soft_format_reward_func</th>
#       <th>rewards / strict_format_reward_func</th>
#       <th>rewards / int_reward_func</th>
#       <th>rewards / correctness_reward_func</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>-0.559500</td>
#       <td>0.919820</td>
#       <td>317.500000</td>
#       <td>0.000000</td>
#       <td>-0.559500</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>-0.000000</td>
#       <td>-0.618667</td>
#       <td>0.821644</td>
#       <td>324.000000</td>
#       <td>0.000000</td>
#       <td>-0.618667</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>-0.949833</td>
#       <td>0.205947</td>
#       <td>255.500000</td>
#       <td>0.000010</td>
#       <td>-0.949833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>-0.209500</td>
#       <td>0.577929</td>
#       <td>280.166687</td>
#       <td>0.000011</td>
#       <td>-0.209500</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>-0.926333</td>
#       <td>0.338566</td>
#       <td>261.500000</td>
#       <td>0.000010</td>
#       <td>-0.926333</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>-0.690000</td>
#       <td>0.808791</td>
#       <td>309.500000</td>
#       <td>0.000010</td>
#       <td>-0.690000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>-0.552167</td>
#       <td>0.647574</td>
#       <td>291.166687</td>
#       <td>0.000010</td>
#       <td>-0.552167</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>-0.619833</td>
#       <td>0.670701</td>
#       <td>256.500000</td>
#       <td>0.000010</td>
#       <td>-0.619833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>-0.254500</td>
#       <td>0.554046</td>
#       <td>191.333344</td>
#       <td>0.000011</td>
#       <td>-0.254500</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>-0.292333</td>
#       <td>0.520116</td>
#       <td>262.666687</td>
#       <td>0.000012</td>
#       <td>-0.292333</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>-0.622833</td>
#       <td>0.668573</td>
#       <td>254.000000</td>
#       <td>0.000017</td>
#       <td>-0.622833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>-0.383833</td>
#       <td>0.850628</td>
#       <td>288.833344</td>
#       <td>0.000015</td>
#       <td>-0.383833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>-0.302333</td>
#       <td>0.468456</td>
#       <td>227.833344</td>
#       <td>0.000025</td>
#       <td>-0.302333</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>-0.346333</td>
#       <td>0.646896</td>
#       <td>284.333344</td>
#       <td>0.000027</td>
#       <td>-0.346333</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000000</td>
#       <td>-0.502833</td>
#       <td>0.419934</td>
#       <td>218.833344</td>
#       <td>0.000020</td>
#       <td>-0.502833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000000</td>
#       <td>-0.156167</td>
#       <td>0.450532</td>
#       <td>265.500000</td>
#       <td>0.000044</td>
#       <td>-0.156167</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.000000</td>
#       <td>-0.232500</td>
#       <td>0.654711</td>
#       <td>252.166672</td>
#       <td>0.000056</td>
#       <td>-0.232500</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.000000</td>
#       <td>-0.987833</td>
#       <td>0.228142</td>
#       <td>262.333344</td>
#       <td>0.000065</td>
#       <td>-0.987833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.000000</td>
#       <td>-0.763000</td>
#       <td>0.653785</td>
#       <td>280.833344</td>
#       <td>0.000089</td>
#       <td>-0.763000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000000</td>
#       <td>-0.466833</td>
#       <td>0.745677</td>
#       <td>293.333344</td>
#       <td>0.000082</td>
#       <td>-0.466833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.000000</td>
#       <td>-0.252500</td>
#       <td>0.523524</td>
#       <td>226.333344</td>
#       <td>0.000418</td>
#       <td>-0.252500</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.000000</td>
#       <td>-0.312000</td>
#       <td>0.573108</td>
#       <td>273.666687</td>
#       <td>0.000238</td>
#       <td>-0.312000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.000000</td>
#       <td>-0.345333</td>
#       <td>0.588057</td>
#       <td>226.500000</td>
#       <td>0.000717</td>
#       <td>-0.345333</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.000000</td>
#       <td>-0.157500</td>
#       <td>0.453923</td>
#       <td>266.333344</td>
#       <td>0.000943</td>
#       <td>-0.157500</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.000000</td>
#       <td>-0.676667</td>
#       <td>0.714077</td>
#       <td>284.500000</td>
#       <td>0.000789</td>
#       <td>-0.676667</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.000100</td>
#       <td>0.003333</td>
#       <td>0.008165</td>
#       <td>242.333344</td>
#       <td>0.002017</td>
#       <td>0.003333</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Now let's try the model we just trained! First, let's first try the model without any GRPO trained:

# %%
text = tokenizer.apply_chat_template([
    {"role" : "user", "content" : "Calculate pi."},
], tokenize = False, add_generation_prompt = True)

from vllm import SamplingParams
sampling_params = SamplingParams(
    temperature = 0.8,
    top_p = 0.95,
    max_tokens = 1024,
)
output = model.fast_generate(
    [text],
    sampling_params = sampling_params,
    lora_request = None,
)[0].outputs[0].text

output
# Out:
# Processed prompts: 100%|██████████| 1/1 [00:51<00:00, 51.81s/it, est. speed input: 0.75 toks/s, output: 17.01 toks/s]
# '**Calculating Pi using Python**\n\nPi (π) is a mathematical constant representing the ratio of a circle\'s circumference to its diameter. Here\'s a simple and efficient way to calculate an approximation of pi using Python.\n\n### Using the Monte Carlo Method\n\nThe Monte Carlo method is a computational algorithm that uses random sampling to approximate a value. In this case, we can use it to estimate pi by generating random points within a square and checking if they fall inside a quarter-circle inscribed within it.\n\n```python\nimport random\nimport math\n\ndef estimate_pi(num_samples):\n    """\n    Estimate the value of pi using the Monte Carlo method.\n\n    Args:\n    num_samples (int): The number of random points to generate.\n\n    Returns:\n    float: An approximation of pi.\n    """\n    points_inside_circle = 0\n\n    for _ in range(num_samples):\n        x, y = random.random(), random.random()\n        distance = x**2 + y**2\n        if distance <= 1:\n            points_inside_circle += 1\n\n    return (points_inside_circle / num_samples) * 4\n\n# Example usage:\nnum_samples = 1000000\napprox_pi = estimate_pi(num_samples)\nprint(f"Approximation of pi with {num_samples} samples: {approx_pi}")\n```\n\nThis code generates `num_samples` random points within the square (-1, -1) to (1, 1) and checks if each point falls inside the quarter-circle. The ratio of points inside the circle to the total number of samples multiplied by 4 gives an approximation of pi.\n\n### Using the Bailey-Borwein-Plouffe Formula\n\nThe Bailey-Borwein-Plouffe (BBP) formula is another way to calculate pi. It\'s a spigot algorithm that uses a series expansion to generate the digits of pi.\n\n```python\ndef bbp_pi(n):\n    """\n    Calculate the Bailey-Borwein-Plouffe formula for pi.\n\n    Args:\n    n (int): The number of terms to use in the series expansion.\n\n    Returns:\n    float: An approximation of pi.\n    """\n    pi = 0.0\n    for k in range(n):\n        pi += (1 / (16 ** k)) * (\n            4 / (8 * k + 1) -\n            2 / (8 * k + 4) -\n            1 / (8 * k + 5) -\n            1 / (8 * k + 6)\n        )\n    return pi\n\n# Example usage:\nn = 100\napprox_pi = bbp_pi(n)\nprint(f"Approximation of pi with {n} terms: {approx_pi}")\n```\n\nThis code calculates an approximation of pi using the BBP formula with `n` terms.\n\n### Using the Gauss-Legendre Algorithm\n\nThe Gauss-Legendre algorithm is another method for calculating pi. It\'s a recursive algorithm that uses an iterative process to improve the estimate of pi.\n\n```python\ndef gauss_legendre(n):\n    """\n    Calculate pi using the Gauss-Legendre algorithm.\n\n    Args:\n    n (int): The number of iterations.\n\n    Returns:\n    float: An approximation of pi.\n    """\n    a, b = 1.0, (1 + math.sqrt(5)) / 2.0\n    t = (1 + math.sqrt(5)) / 4.0\n    p = 1.0\n    for _ in range(n):\n        a, b = (a + b) / 2.0, math.sqrt(a * b)\n        t -= p * (a - b)\n        p *= 2.0\n        a = a + t / p\n        b = math.sqrt(b - t / p)\n    return a * b * 16.0\n\n# Example usage:\nn = 100\napprox_pi = gauss_legendre(n)\nprint(f"Approximation of pi with {n} iterations: {approx_pi}")\n```\n\nThis code calculates an approximation of pi using the Gauss-Legendre algorithm with `n` iterations.\n\nRemember that these are simplified examples and may not be the most efficient or accurate methods for calculating pi. For more accurate calculations, you can use specialized libraries or software.'

# %% [markdown]
# And now with the LoRA we just trained with GRPO - we first save the LoRA first!

# %%
model.save_lora("grpo_saved_lora")

# %% [markdown]
# Now we load the LoRA and test:

# %%
text = tokenizer.apply_chat_template([
    {"role" : "system", "content" : SYSTEM_PROMPT},
    {"role" : "user", "content" : "Calculate pi."},
], tokenize = False, add_generation_prompt = True)

from vllm import SamplingParams
sampling_params = SamplingParams(
    temperature = 0.8,
    top_p = 0.95,
    max_tokens = 1024,
)
output = model.fast_generate(
    text,
    sampling_params = sampling_params,
    lora_request = model.load_lora("grpo_saved_lora"),
)[0].outputs[0].text

output
# Out:
# Processed prompts: 100%|██████████| 1/1 [00:23<00:00, 23.17s/it, est. speed input: 2.63 toks/s, output: 15.80 toks/s]
# 'Calculating pi to a high degree of accuracy is a complex task that requires a large amount of computational power. However, I can provide you with an approximate value of pi or show you a simple method to calculate it.\n\nOne of the simplest methods to calculate pi is the Leibniz formula, which is an infinite series:\n\npi/4 = 1 - 1/3 + 1/5 - 1/7 + 1/9 - ...\n\nThis series can be used to calculate an approximation of pi.\n\n<reasoning>\npi = 4 * (1 - 1/3 + 1/5 - 1/7 + 1/9 - ...)\n</reasoning>\n\nThis is a simple, yet effective method to calculate pi. However, the more terms you use, the more accurate the result will be.\n\nTo calculate pi to a high degree of accuracy, you would need to use a computer program to perform the calculation.\n\n<answer>\n3.141592653589793 (approximately)\n</answer>\n\nFor a more accurate result, I can provide you with a Python code snippet to calculate pi:\n\n```python\nimport math\n\ndef calculate_pi(n):\n    pi = 0.0\n    for i in range(n):\n        pi += ((-1)**i) / (2 * i + 1)\n    return 4 * pi\n\nn = 1000000  # Increase the value of n for more accurate result\nprint(calculate_pi(n))\n```\n\nThis code uses the Leibniz formula to calculate pi to a high degree of accuracy. The value of `n` can be increased for a more accurate result.\n\nNote that this is just one of many methods to calculate pi, and there are more complex algorithms available for more accurate results.'

# %% [markdown]
# Our reasoning model is much better - it's not always correct, since we only trained it for an hour or so - it'll be better if we extend the sequence length and train for longer!

# %% [markdown]
# <a name="Save"></a>
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False: model.save_pretrained_merged("model", tokenizer, save_method = "lora",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "lora", token = "")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.
#
# [**NEW**] To finetune and auto export to Ollama, try our [Ollama notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("model", tokenizer,)
# Remember to go to https://huggingface.co/settings/tokens for a token!
# And change hf to your username!
if False: model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# Save to multiple GGUF options - much faster if you want multiple!
if False:
    model.push_to_hub_gguf(
        "hf/model", # Change hf to your username!
        tokenizer,
        quantization_method = ["q4_k_m", "q8_0", "q5_k_m",],
        token = "",
    )

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in llama.cpp or a UI based system like Jan or Open WebUI. You can install Jan [here](https://github.com/janhq/jan) and Open WebUI [here](https://github.com/open-webui/open-webui)
#
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
